# %%
# !pip install sweetviz
# !pip install kaggle
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 43.6 MB/s eta 0:00:00
# ...

# %%
# !kaggle datasets download -d nagasai524/nyc-taxi-trip-records-from-jan-2023-to-jun-2023
# !unzip nyc-taxi-trip-records-from-jan-2023-to-jun-2023.zip -d data/
# Out:
# Dataset URL: https://www.kaggle.com/datasets/nagasai524/nyc-taxi-trip-records-from-jan-2023-to-jun-2023
# License(s): U.S. Government Works
# ...
#  98% 398M/407M [00:04<00:00, 69.8MB/s]
# 100% 407M/407M [00:04<00:00, 86.2MB/s]
# Archive:  nyc-taxi-trip-records-from-jan-2023-to-jun-2023.zip
#   inflating: data/nyc_yellow_taxi_trip_records_from_Jan_to_Aug_2023.csv

# %%
import pandas as pd

columns = ['tpep_pickup_datetime', 'trip_distance', 'fare_amount', 'passenger_count', 'payment_type']
df_sample = pd.read_csv('/content/data/nyc_yellow_taxi_trip_records_from_Jan_to_Aug_2023.csv', usecols=columns, nrows=100000)

df_sample.head()
# Out:
#   tpep_pickup_datetime  passenger_count  trip_distance  payment_type  \
# 0  2023-06-30 23:59:59              2.0          17.62             1
# 1  2023-06-30 23:59:57              1.0           3.32             1
# 2  2023-06-30 23:59:55              1.0           2.80             1
# 3  2023-06-30 23:59:55              1.0           0.89             1
# 4  2023-06-30 23:59:55              4.0           1.56             1
#
#    fare_amount
# 0         70.0
# 1         18.4
# 2         14.9
# 3          7.2
# 4         10.0

# %%
import sweetviz as sv

report = sv.analyze(df_sample)

report.show_html('auto_eda_report.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report auto_eda_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

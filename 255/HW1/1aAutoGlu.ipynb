# %%
# !pip install kaggle
# !mkdir -p /root/.config/kaggle
# !cp /content/kaggle.json /root/.config/kaggle/
# !chmod 600 /root/.config/kaggle/kaggle.json
# !kaggle competitions download -c ieee-fraud-detection
# !unzip /content/ieee-fraud-detection.zip -d /content/IEEEfraud
# Out:
# ...
#  91% 107M/118M [00:01<00:00, 92.3MB/s]
# 100% 118M/118M [00:01<00:00, 112MB/s]
# Archive:  /content/ieee-fraud-detection.zip
#   inflating: /content/IEEEfraud/sample_submission.csv
#   inflating: /content/IEEEfraud/test_identity.csv
#   inflating: /content/IEEEfraud/test_transaction.csv
#   inflating: /content/IEEEfraud/train_identity.csv
#   inflating: /content/IEEEfraud/train_transaction.csv

# %%
# !pip install autogluon.tabular

import pandas as pd
import numpy as np
from autogluon.tabular import TabularPredictor

directory = '/content/IEEEfraud'
label = 'isFraud'
eval_metric = 'roc_auc'
save_path = directory + 'AutoGluonModels/'

train_identity = pd.read_csv(directory+'/train_identity.csv')
train_transaction = pd.read_csv(directory+'/train_transaction.csv')

train_data = pd.merge(train_transaction, train_identity, on='TransactionID', how='left')
predictor = TabularPredictor(label=label, eval_metric=eval_metric, path=save_path, verbosity=3).fit(
    train_data, presets='best_quality', time_limit=600
)

results = predictor.fit_summary()
# Out:
# ...
# Verbosity: 3 (Detailed Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.12
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP PREEMPT_DYNAMIC Thu Jun 27 21:05:47 UTC 2024
# CPU Count:          8
# GPU Count:          1
# Memory Avail:       40.89 GB / 50.99 GB (80.2%)
# Disk Space Avail:   195.80 GB / 235.68 GB (83.1%)
# ...
# Presets specified: ['best_quality']
# ============ fit kwarg info ============
# User Specified kwargs:
# {'auto_stack': True, 'num_bag_sets': 1}
# Full kwargs:
# {'_feature_generator_kwargs': None,
#  '_save_bag_folds': None,
#  'ag_args': None,
#  'ag_args_ensemble': None,
#  'ag_args_fit': None,
#  'auto_stack': True,
#  'calibrate': 'auto',
#  'ds_args': {'clean_up_fits': True,
#              'detection_time_frac': 0.25,
#              'enable_ray_logging': True,
#              'holdout_data': None,
#              'holdout_frac': 0.1111111111111111,
# ...

# %%
test_identity = pd.read_csv(directory+'/test_identity.csv')
test_transaction = pd.read_csv(directory+'/test_transaction.csv')
test_data = pd.merge(test_transaction, test_identity, on='TransactionID', how='left')

# %%
for col in missing_cols_in_test:
    test_data[col] = -999
y_predproba = predictor.predict_proba(test_data)
y_predproba.head(5)
# Out:
# Loading: /content/IEEEfraudAutoGluonModels/models/RandomForestGini_BAG_L1/model.pkl
# Loading: /content/IEEEfraudAutoGluonModels/models/WeightedEnsemble_L2/model.pkl
#           0         1
# 0  0.940260  0.059740
# 1  0.903038  0.096962
# 2  0.828832  0.171168
# 3  0.991395  0.008605
# 4  0.984250  0.015750

# %%
predictor.positive_class
# Out:
# 1

# %%
y_predproba = predictor.predict_proba(test_data, as_multiclass=False)
# Out:
# Loading: /content/IEEEfraudAutoGluonModels/models/RandomForestGini_BAG_L1/model.pkl
# Loading: /content/IEEEfraudAutoGluonModels/models/WeightedEnsemble_L2/model.pkl

# %%
directory = '/content/IEEEfraud'
save_path = directory + '/AutoGluonModels/'
submission = pd.read_csv(directory+'/sample_submission.csv')
submission['isFraud'] = y_predproba
submission.head()


submission.to_csv(directory + '/my_submission.csv', index=False)


# !kaggle competitions submit -c ieee-fraud-detection -f /content/IEEEfraud/my_submission.csv -m "my first submission"
# Out:
# Found 'my_submission.csv' at: /content/IEEEfraud/my_submission.csv
# 100% 9.27M/9.27M [00:00<00:00, 35.0MB/s]
# Successfully submitted to IEEE-CIS Fraud Detection

# %%
# !pip install kaggle
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d navoneel/brain-mri-images-for-brain-tumor-detection
# !unzip brain-mri-images-for-brain-tumor-detection.zip -d /content/brain_mri_images
# !kaggle datasets download -d andrewmvd/heart-failure-clinical-data
# !unzip heart-failure-clinical-data.zip -d /content/heart_failure_data
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.6.17)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2024.8.30)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.6)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.2.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.10)
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory
# Dataset URL: https://www.kaggle.com/datasets/navoneel/brain-mri-images-for-brain-tumor-detection
# License(s): copyright-authors
# brain-mri-images-for-brain-tumor-detection.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  brain-mri-images-for-brain-tumor-detection.zip
# replace /content/brain_mri_images/brain_tumor_dataset/no/1 no.jpeg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/1 no.jpeg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/10 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/11 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/12 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/13 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/14 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/15 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/17 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/18 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/19 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/2 no.jpeg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/20 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/21 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/22 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/23 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/24 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/25 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/26 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/27 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/28 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/29 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/3 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/30 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/31 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/32 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/33 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/34 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/35 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/36 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/37 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/38 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/39 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/4 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/40 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/41 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/42 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/43 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/44no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/45 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/46 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/47 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/48 no.jpeg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/49 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/5 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/50 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/6 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/7 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/8 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/9 no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/N1.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/N11.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/N15.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/N16.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/N17.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/N19.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/N2.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/N20.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/N21.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/N22.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/N26.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/N3.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/N5.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/N6.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/No11.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/No12.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/No13.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/No14.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/No15.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/No16.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/No17.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/No18.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/No19.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/No20.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/No21.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/No22.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/no 1.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/no 10.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/no 100.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/no 2.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/no 3.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/no 4.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/no 5.jpeg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/no 6.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/no 7.jpeg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/no 8.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/no 89.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/no 9.png
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/no 90.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/no 91.jpeg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/no 92.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/no 923.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/no 94.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/no 95.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/no 96.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/no 97.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/no 98.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/no 99.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/no/no.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y1.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y10.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y100.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y101.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y102.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y103.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y104.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y105.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y106.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y107.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y108.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y109.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y11.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y111.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y112.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y113.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y114.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y115.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y116.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y117.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y12.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y120.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y13.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y14.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y146.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y147.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y148.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y15.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y153.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y154.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y155.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y156.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y157.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y158.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y159.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y16.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y160.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y161.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y162.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y163.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y164.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y165.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y166.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y167.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y168.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y169.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y17.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y170.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y18.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y180.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y181.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y182.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y183.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y184.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y185.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y186.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y187.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y188.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y19.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y192.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y193.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y194.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y195.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y2.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y20.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y21.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y22.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y23.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y24.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y242.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y243.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y244.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y245.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y246.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y247.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y248.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y249.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y25.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y250.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y251.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y252.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y253.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y254.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y255.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y256.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y257.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y258.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y259.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y26.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y27.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y28.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y29.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y3.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y30.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y31.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y32.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y33.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y34.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y35.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y36.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y37.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y38.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y39.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y4.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y40.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y41.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y42.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y44.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y45.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y46.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y47.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y49.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y50.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y51.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y52.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y53.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y54.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y55.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y56.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y58.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y59.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y6.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y60.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y61.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y62.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y65.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y66.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y67.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y69.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y7.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y70.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y71.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y73.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y74.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y75.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y76.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y77.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y78.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y79.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y8.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y81.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y82.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y85.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y86.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y89.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y9.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y90.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y91.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y92.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y92.png
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y95.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y96.jpg
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/Y97.JPG
#   inflating: /content/brain_mri_images/brain_tumor_dataset/yes/
#   inflating: /content/brain_mri_images/yes/Y62.jpg
#   inflating: /content/brain_mri_images/yes/Y65.JPG
#   inflating: /content/brain_mri_images/yes/Y66.JPG
#   inflating: /content/brain_mri_images/yes/Y67.JPG
#   inflating: /content/brain_mri_images/yes/Y69.jpg
#   inflating: /content/brain_mri_images/yes/Y7.jpg
#   inflating: /content/brain_mri_images/yes/Y70.jpg
#   inflating: /content/brain_mri_images/yes/Y71.JPG
#   inflating: /content/brain_mri_images/yes/Y73.jpg
#   inflating: /content/brain_mri_images/yes/Y74.jpg
#   inflating: /content/brain_mri_images/yes/Y75.JPG
#   inflating: /content/brain_mri_images/yes/Y76.jpg
#   inflating: /content/brain_mri_images/yes/Y77.jpg
#   inflating: /content/brain_mri_images/yes/Y78.jpg
#   inflating: /content/brain_mri_images/yes/Y79.jpg
#   inflating: /content/brain_mri_images/yes/Y8.jpg
#   inflating: /content/brain_mri_images/yes/Y81.jpg
#   inflating: /content/brain_mri_images/yes/Y82.jpg
#   inflating: /content/brain_mri_images/yes/Y85.JPG
#   inflating: /content/brain_mri_images/yes/Y86.JPG
#   inflating: /content/brain_mri_images/yes/Y89.JPG
#   inflating: /content/brain_mri_images/yes/Y9.jpg
#   inflating: /content/brain_mri_images/yes/Y90.jpg
#   inflating: /content/brain_mri_images/yes/Y91.jpg
#   inflating: /content/brain_mri_images/yes/Y92.jpg
#   inflating: /content/brain_mri_images/yes/Y92.png
#   inflating: /content/brain_mri_images/yes/Y95.jpg
#   inflating: /content/brain_mri_images/yes/Y96.jpg
#   inflating: /content/brain_mri_images/yes/Y97.JPG
#   inflating: /content/brain_mri_images/yes/Y98.JPG
#   inflating: /content/brain_mri_images/yes/Y99.JPG
# Dataset URL: https://www.kaggle.com/datasets/andrewmvd/heart-failure-clinical-data
# License(s): Attribution 4.0 International (CC BY 4.0)
# heart-failure-clinical-data.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  heart-failure-clinical-data.zip
# replace /content/heart_failure_data/heart_failure_clinical_records_dataset.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: /content/heart_failure_data/heart_failure_clinical_records_dataset.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

# !pip install --upgrade umap-learn


import plotly.express as px
from sklearn.manifold import TSNE, Isomap
from umap import UMAP
from sklearn.manifold import MDS
from sklearn.decomposition import KernelPCA, FactorAnalysis

from sklearn.cluster import AgglomerativeClustering


tabular_path = '/content/heart_failure_data/heart_failure_clinical_records_dataset.csv'
tabular_data = pd.read_csv(tabular_path)

print("Tabular Dataset Preview:")
print(tabular_data.head())

image_dataset_path = '/content/brain_mri_images'
image_data_generator = ImageDataGenerator(rescale=1.0/255.0)
batch_size = 32
target_size = (128, 128)

if not os.path.exists(image_dataset_path):
    print(f"Error: Image dataset not found at {image_dataset_path}")

# Prepare image dataset
image_data = image_data_generator.flow_from_directory(
    image_dataset_path,
    target_size=target_size,
    batch_size=batch_size,
    class_mode=None,
    shuffle=True
)

# Step 3: Preprocess Datasets

if tabular_data.isnull().sum().sum() > 0:
    tabular_data.dropna(inplace=True)

scaler = StandardScaler()
tabular_data_scaled = scaler.fit_transform(tabular_data.iloc[:, :-1])  # Exclude target column if present

print(f"Tabular Dataset Shape: {tabular_data.shape}")
print(f"Image Dataset Shape: {image_data.n} images of size {target_size}")

np.save("tabular_data_scaled.npy", tabular_data_scaled)

plt.figure(figsize=(10, 10))

batch = next(image_data)

for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.imshow(batch[i])
    plt.axis('off')

plt.suptitle("Sample Images from the Brain MRI Dataset")
plt.show()
# Out:
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.10/dist-packages (0.5.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.5.2)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.5.13)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from umap-learn) (4.66.6)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn) (0.43.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pynndescent>=0.5->umap-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->umap-learn) (3.5.0)
# Tabular Dataset Preview:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1
# Found 506 images belonging to 3 classes.
# Tabular Dataset Shape: (299, 13)
# Image Dataset Shape: 506 images of size (128, 128)

# %%
from sklearn.manifold import LocallyLinearEmbedding

# Apply LLE to Tabular Dataset
lle = LocallyLinearEmbedding(n_neighbors=10, n_components=2, random_state=42)
lle_transformed = lle.fit_transform(tabular_data_scaled)

# Visualize LLE results
plt.figure(figsize=(10, 6))
plt.scatter(lle_transformed[:, 0], lle_transformed[:, 1], c='blue', edgecolor='k')
plt.title("LLE Transformation of Tabular Dataset")
plt.xlabel("Component 1")
plt.ylabel("Component 2")
plt.grid(True)
plt.show()

# %%
from sklearn.manifold import TSNE
import plotly.express as px

# Apply t-SNE to Tabular Dataset
tsne = TSNE(n_components=2, random_state=42, perplexity=30, n_iter=300)
tsne_transformed = tsne.fit_transform(tabular_data_scaled)

tsne_df = pd.DataFrame(tsne_transformed, columns=['Component 1', 'Component 2'])

fig = px.scatter(tsne_df, x='Component 1', y='Component 2',
                 title="t-SNE Visualization of Tabular Data",
                 labels={'Component 1': 't-SNE Component 1', 'Component 2': 't-SNE Component 2'})
fig.show()
image_batch = next(image_data)  # Get a batch of images
image_batch_flat = image_batch.reshape(image_batch.shape[0], -1)  # Flatten each image

tsne_images = TSNE(n_components=2, random_state=42, perplexity=30, n_iter=300)
tsne_images_transformed = tsne_images.fit_transform(image_batch_flat)

tsne_images_df = pd.DataFrame(tsne_images_transformed, columns=['Component 1', 'Component 2'])

fig = px.scatter(tsne_images_df, x='Component 1', y='Component 2',
                 title="t-SNE Visualization of Image Data",
                 labels={'Component 1': 't-SNE Component 1', 'Component 2': 't-SNE Component 2'})
fig.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/manifold/_t_sne.py:1162: FutureWarning:
#
# 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e02998fb-40da-4d17-a8fd-d3c58c3dbc59" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e02998fb-40da-4d17-a8fd-d3c58c3dbc59")) {                    Plotly.newPlot(                        "e02998fb-40da-4d17-a8fd-d3c58c3dbc59",                        [{"hovertemplate":"t-SNE Component 1=%{x}\u003cbr\u003et-SNE Component 2=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-1.0869784,-11.48999,7.783522,-0.5947601,1.8145194,-1.9195584,-0.24133079,3.2355804,-9.066049,-12.926255,-1.9530281,6.4597564,-0.7718638,-2.0698483,-6.6536646,2.1905634,2.0090027,0.34262836,-7.8004727,1.4069588,-7.6117573,-6.659697,4.7960534,2.0692558,-7.163995,9.899513,-8.629403,9.342518,-2.8992078,10.27393,3.8836017,1.9427642,0.7105529,-0.69154316,-4.841353,-0.23326266,2.5936446,-10.101457,0.4189753,-6.258973,6.6724567,10.08448,9.334164,-4.8174953,-8.21537,10.5476885,-0.54643273,9.545612,-2.5198133,-5.7
# /usr/local/lib/python3.10/dist-packages/sklearn/manifold/_t_sne.py:1162: FutureWarning:
#
# 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="902b3d25-6766-444e-85fd-5b69a9ab005d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("902b3d25-6766-444e-85fd-5b69a9ab005d")) {                    Plotly.newPlot(                        "902b3d25-6766-444e-85fd-5b69a9ab005d",                        [{"hovertemplate":"t-SNE Component 1=%{x}\u003cbr\u003et-SNE Component 2=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[14.7499275,-12.020268,1.7720774,3.8193672,1.1012614,5.8252,-12.504181,-7.433037,-8.342566,8.2661915,10.903352,9.270753,0.7306112,14.187333,-2.8058858,-1.3302772,6.9228754,16.235344,-13.163752,2.9886475,6.4668055,-4.9038534,12.834389,3.811431,10.143046,-8.142014,-3.5502796,-2.0606194,-7.502133,4.6392226,-2.5404232,-0.77172625],"xaxis":"x","y":[-8.3373375,12.863629,1.2227235,-13.209572,-3.5698524,-2.571328,2.8590925,0.18328528,-5.59191,6.906569,0.48050928,-11.136592,9.73669,4.9144926,0.17603813,14.610191,12.820793,-1.4027474,-3.2189393,5.8982086,2.3428667,10.193853,10.941105,17.48127,-4.9248786,6.108045,-4.997382,-14.367964,-11.067925,-7.738492,4.967973,-9.040044],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{" ...

# %%
from sklearn.manifold import Isomap

# Apply ISOMAP to Tabular Dataset
isomap = Isomap(n_neighbors=10, n_components=2)
isomap_transformed = isomap.fit_transform(tabular_data_scaled)

# Visualize ISOMAP results
plt.figure(figsize=(10, 6))
plt.scatter(isomap_transformed[:, 0], isomap_transformed[:, 1], c='blue', edgecolor='k')
plt.title("ISOMAP Transformation of Tabular Dataset")
plt.xlabel("Component 1")
plt.ylabel("Component 2")
plt.grid(True)
plt.show()

# %%
image_batch = next(image_data)
image_batch_flat = image_batch.reshape(image_batch.shape[0], -1)

# Apply ISOMAP to Image Dataset
isomap_images = Isomap(n_neighbors=10, n_components=2)
isomap_images_transformed = isomap_images.fit_transform(image_batch_flat)

# Visualize ISOMAP results for Image Data
plt.figure(figsize=(10, 6))
plt.scatter(isomap_images_transformed[:, 0], isomap_images_transformed[:, 1], c='green', edgecolor='k')
plt.title("ISOMAP Transformation of Image Dataset")
plt.xlabel("Component 1")
plt.ylabel("Component 2")
plt.grid(True)
plt.show()

# %%
from umap import UMAP

# Apply UMAP to Tabular Dataset
umap = UMAP(n_neighbors=15, n_components=2, random_state=42)
umap_transformed = umap.fit_transform(tabular_data_scaled)

umap_df = pd.DataFrame(umap_transformed, columns=['Component 1', 'Component 2'])

fig = px.scatter(umap_df, x='Component 1', y='Component 2',
                 title="UMAP Visualization of Tabular Data",
                 labels={'Component 1': 'UMAP Component 1', 'Component 2': 'UMAP Component 2'})
fig.show()
image_batch = next(image_data)
image_batch_flat = image_batch.reshape(image_batch.shape[0], -1)

# Apply UMAP to Image Dataset
umap_images = UMAP(n_neighbors=15, n_components=2, random_state=42)
umap_images_transformed = umap_images.fit_transform(image_batch_flat)

umap_images_df = pd.DataFrame(umap_images_transformed, columns=['Component 1', 'Component 2'])

fig = px.scatter(umap_images_df, x='Component 1', y='Component 2',
                 title="UMAP Visualization of Image Data",
                 labels={'Component 1': 'UMAP Component 1', 'Component 2': 'UMAP Component 2'})
fig.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/umap/umap_.py:1952: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3
169,5.4239345,5.6923532,3.7454677,6.111892,5.1032624,3.4639878,5.73006,8.886815,9.906399,6.2677712,4.8573895,3.5100229,9.505922,5.95805,5.9857535,4.0550346,4.0598354,8.849124,6.5776005,10.0066805,9.866012,5.456104,5.752936,5.7053003,2.5306149,9.720937,3.454353,8.6303,8.475369,2.2702234,5.752423,4.985786,6.5466805,5.9557123,8.740962,3.315017,3.661719,3.1999528,5.814005,3.6058967,5.887611,8.176065,3.8895543,5.2622976,5.055951,9.13477,6.2109222,1.7474194,5.079168,2.3628788,6.005118,9.895225,8.254301,5.195272,2.9398594,5.6784687,7.64593,3.099251,3.9760146,6.349048,8.900646,3.6144853,3.8449585,5.9119253,2.6951678,2.928647,6.221394,8.756084,7.9947095,8.613022,6.6132197,5.0269833,6.2734623,2.8728166,3.3568666,3.9109967,2.9621942,6.1695247,8.983619,8.942767,8.128675,3.8172555,2.8142273,8.515215,9.328985],"xaxis":"x","y":[1.4040293,3.1703417,1.8676072,1.7821873,1.4290447,0.90984815,1.7664987,1.0214232,2.5080576,2.040617,1.3235226,1.0642176,1.7573266,1.0689298,0.36815652,2.1504421,2.2006135,1.8498535,0.29180342,1.6045542,0.34876698,0.93326896,0.5833831,3.5642614,0.5076434,1.2089361,0.38019106,0.6426709,2.1557264,1.0983852,0.48660094,2.6403003,1.083 ...
# /usr/local/lib/python3.10/dist-packages/umap/umap_.py:1952: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3011329b-e895-422e-be4b-bbd8c64b88ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3011329b-e895-422e-be4b-bbd8c64b88ef")) {                    Plotly.newPlot(                        "3011329b-e895-422e-be4b-bbd8c64b88ef",                        [{"hovertemplate":"UMAP Component 1=%{x}\u003cbr\u003eUMAP Component 2=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[7.928492,8.004548,7.363801,8.418103,8.099941,8.951546,9.576976,7.227725,9.197963,7.9118156,8.33954,8.703423,9.008197,8.438932,8.960594,8.024067,7.283391,7.575591,9.274004,7.5228744,7.951132,7.555144,7.813588,7.0428205,9.7701435,8.213354,8.445097,9.500305,7.7266974,8.576145,6.864349,8.793888],"xaxis":"x","y":[-6.689909,-4.9399934,-5.430456,-7.672406,-5.9994664,-8.35084,-7.5404243,-7.0720963,-7.771812,-5.363096,-8.576226,-6.1168246,-5.7316666,-6.689174,-7.4025755,-8.199522,-6.03259,-5.52076,-7.00367,-7.788559,-7.1457257,-6.0675225,-7.295994,-6.3602805,-7.1269073,-6.2535806,-5.354795,-6.151649,-8.428214,-8.277006,-7.239753,-7.270329],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"sca ...

# %%
from sklearn.manifold import MDS

# Apply MDS to Tabular Dataset
mds = MDS(n_components=2, random_state=42)
mds_transformed = mds.fit_transform(tabular_data_scaled)

plt.figure(figsize=(10, 6))
plt.scatter(mds_transformed[:, 0], mds_transformed[:, 1], c='blue', edgecolor='k')
plt.title("MDS Transformation of Tabular Dataset")
plt.xlabel("Component 1")
plt.ylabel("Component 2")
plt.grid(True)
plt.show()

image_batch = next(image_data)
image_batch_flat = image_batch.reshape(image_batch.shape[0], -1)

mds_images = MDS(n_components=2, random_state=42)
mds_images_transformed = mds_images.fit_transform(image_batch_flat)

plt.figure(figsize=(10, 6))
plt.scatter(mds_images_transformed[:, 0], mds_images_transformed[:, 1], c='green', edgecolor='k')
plt.title("MDS Transformation of Image Dataset")
plt.xlabel("Component 1")
plt.ylabel("Component 2")
plt.grid(True)
plt.show()

# %%
from sklearn.decomposition import PCA

randomized_pca = PCA(n_components=2, svd_solver='randomized', random_state=42)
randomized_pca_transformed = randomized_pca.fit_transform(tabular_data_scaled)

# Visualize Randomized PCA results
plt.figure(figsize=(10, 6))
plt.scatter(randomized_pca_transformed[:, 0], randomized_pca_transformed[:, 1], c='blue', edgecolor='k')
plt.title("Randomized PCA Transformation of Tabular Dataset")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.grid(True)
plt.show()
from sklearn.decomposition import KernelPCA

# Apply Kernel PCA to Tabular Dataset
kernel_pca = KernelPCA(n_components=2, kernel='rbf', gamma=0.04, random_state=42)
kernel_pca_transformed = kernel_pca.fit_transform(tabular_data_scaled)

# Visualize Kernel PCA results
plt.figure(figsize=(10, 6))
plt.scatter(kernel_pca_transformed[:, 0], kernel_pca_transformed[:, 1], c='green', edgecolor='k')
plt.title("Kernel PCA Transformation of Tabular Dataset")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.grid(True)
plt.show()
from sklearn.decomposition import IncrementalPCA

incremental_pca = IncrementalPCA(n_components=2)
incremental_pca_transformed = incremental_pca.fit_transform(tabular_data_scaled)

plt.figure(figsize=(10, 6))
plt.scatter(incremental_pca_transformed[:, 0], incremental_pca_transformed[:, 1], c='purple', edgecolor='k')
plt.title("Incremental PCA Transformation of Tabular Dataset")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.grid(True)
plt.show()

# %%
from sklearn.decomposition import FactorAnalysis

# Apply Factor Analysis to Tabular Dataset
factor_analysis = FactorAnalysis(n_components=2, random_state=42)
factor_analysis_transformed = factor_analysis.fit_transform(tabular_data_scaled)

# Visualize Factor Analysis results
plt.figure(figsize=(10, 6))
plt.scatter(factor_analysis_transformed[:, 0], factor_analysis_transformed[:, 1], c='orange', edgecolor='k')
plt.title("Factor Analysis Transformation of Tabular Dataset")
plt.xlabel("Factor 1")
plt.ylabel("Factor 2")
plt.grid(True)
plt.show()

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Flatten, Reshape

# Define Autoencoder Architecture
input_dim = image_batch_flat.shape[1]

input_layer = Input(shape=(input_dim,))
encoded = Dense(128, activation='relu')(input_layer)
encoded = Dense(64, activation='relu')(encoded)

decoded = Dense(128, activation='relu')(encoded)
decoded = Dense(input_dim, activation='sigmoid')(decoded)

autoencoder = Model(input_layer, decoded)
autoencoder.compile(optimizer='adam', loss='mse')

autoencoder.fit(image_batch_flat, image_batch_flat, epochs=10, batch_size=32, shuffle=True, verbose=1)

encoder = Model(input_layer, encoded)

autoencoder_transformed = encoder.predict(image_batch_flat)

plt.figure(figsize=(10, 6))
plt.scatter(autoencoder_transformed[:, 0], autoencoder_transformed[:, 1], c='magenta', edgecolor='k')
plt.title("Autoencoder Transformation of Image Dataset")
plt.xlabel("Latent Dimension 1")
plt.ylabel("Latent Dimension 2")
plt.grid(True)
plt.show()
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.1216
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1212
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1169
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1022
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0791
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0620
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0564
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0546
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0539
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0529
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
